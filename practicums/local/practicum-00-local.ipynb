# %% [markdown]
# CPSC 8810 Machine Learning for Biomedical Applications
# # Practicum 00 - Setting up and testing Python

# %% [markdown]
# __Task 1__
#
# Read *Assignment-Resources-Colab-git.pdf* in Canvas under *Files->Assignment resources* which provides details on using Google Colab and git.

# %% [markdown]
# __Task 2__
#
# Edit this cell by adding text detailing your learning objectives for BMIN 5200.

# %% [markdown]
# __Task 3__
#
# If you have not done so already, clone the course [gitlab repository ](https://git.rcd.clemson.edu/amasino/cpsc-8810-ml-biomed) to your computing environment as described in the file *Assignment-Resources-Colab-git.pdf*.

# %% [markdown]
# __Task 4__
#
# Install the Python libraries need for this course. These are specified in the *requirements.txt* file contained in the repository - this will be udpated throughout the semester. It is strongly recommended that you use a Python environment management system for this task such as [virtualenv](https://virtualenv.pypa.io/en/latest/) or [miniconda](https://docs.conda.io/en/latest/miniconda.html).

# %% [markdown]
# __Task 5__
#
# Execute the code cell below to test the repository *src* direcorty is accessible and that the Python libraries required for the course assignments are installed. If successful, the cell output will be of the form:
# `Hello, YOUR_NAME. Your Colab connection was successful!`

# %%
import numpy as np
import sys
sys.path.append("../../src") # alternatively, you can add the project to your virtual environment using pip install -e .
from util import test_colab_connection

YOUR_NAME = "ADD YOUR NAME HERE"
test_colab_connection(YOUR_NAME)

# %% [markdown]
# __Task 6__
#
# In the code cell below, write Python code that will:
#
# - Print the object 'myText'
# - Print the index to the letter 'W'
# - Print only the word 'Hello' in myText
# - Print myText in reverse order (i.e. yielding 'dlroW olleH')

# %%
myText = 'Hello World!'

# %% [markdown]
# __Task 7__
#
# In the code cell below:
#
# - Write Python function called 'sum_three' that takes three arguments and returns zero if the arguments are all equal and their sum otherwise
# - Print the output of this function in the following four scenarios (2,1,2), (3,2,2), (2,2,2), (1,2,3)

# %%
# def sum_three

# %% [markdown]
# __Task 8__
#
# In the code cell below:
#  - Add items [7, 8, 9] to the list `l` using the extend method
#  - Sort the list in descending order and print it
#  - Pop an item from the list and print it
#  - Print the remainder of the list in reverse order

# %%
l = [1, 5, 6, 3, 4, 2]

# %% [markdown]
# __Task 9__
#
# In the code cell below, sum the `3 X 2` numpy array, `x`, separately along each axis and print the two results.

# %%
import numpy as np

x = np.array([[1, 100], [2, 200], [3, 300]])
