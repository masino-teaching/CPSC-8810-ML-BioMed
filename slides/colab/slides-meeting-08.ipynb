# %% [markdown]
# *This* notebook contains code used to create figures in the powerpoint presentation, 8810-ML4BA-meeting-8-log-reg.pptx

# %% [markdown]
# Create simulated regression data

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the sigmoid function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Generate a range of values from -10 to 10
x = np.linspace(-10, 10, 100)

# Apply the sigmoid function to these values
y = sigmoid(x)

# Plot the function
plt.plot(x, y, color='purple')
plt.title('Sigmoid Function')
plt.xlabel('z')
plt.ylabel('sigmoid(z)')
plt.grid(True)
plt.show()
